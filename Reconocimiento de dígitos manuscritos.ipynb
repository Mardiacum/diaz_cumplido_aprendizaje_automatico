# %% [markdown]
# Aprendizaje Automatico. Actividad 2
#
# Maria Araceli Díaz Cumplido

# %% [markdown]
# # Procesamiento de imágenes

# %% [markdown]
# Mejora el código de keras_model.py visto en la clase sobre Deep Learning para conseguir el mejor resultado posible en el problema de reconocimiento de dígitos manuscritos.
#
# Entrega este cuaderno con el código modificado y ejecutado, indicando la accuracy del modelo y otras métricas de clasificación que consideres interesantes.

# %%
import numpy as np
from keras.layers import Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from keras.losses import categorical_crossentropy
from keras.models import Sequential
from keras.utils import to_categorical
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from tensorflow import keras

# %%
EPOCHS = 10


def make_model(output_dim, dense_layer_sizes=[40], filters=20, kernel_size=(3, 3),pool_size=(2, 2), dropout=0.25):
    
    model = Sequential()
    # Add pair of convolutional-pooling hidden layers
    model.add(Conv2D(filters, kernel_size, activation='relu'))
    model.add(MaxPooling2D(pool_size=pool_size))
    # Add the flatten layer before the dense ones
    model.add(Flatten())
    # Add the dense hidden layers
    for layer_size in dense_layer_sizes:
        model.add(Dense(layer_size, activation='relu'))
    # Add a dropout layer to avoid overfitting
    model.add(Dropout(dropout))
    # Add the output layer
    model.add(Dense(output_dim, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',
                  metrics=['accuracy'])
    return model


def main():

    # Train
    data = np.loadtxt('/content/sample_data/data/train.csv', dtype='f8', delimiter=',', skiprows=1)
    X, y = data[:, 1:], data[:, 0]
    input_shape = (28, 28, 1)
    X = X.reshape(X.shape[0], *input_shape).astype('float32') / 255
    num_classes = len(np.unique(y))
    classifier = KerasClassifier(make_model, output_dim=num_classes,epochs=EPOCHS)
    search_space = {'dense_layer_sizes': [[32], [32, 32]], 'filters': [8, 16]}
    estimator = GridSearchCV(classifier, search_space, cv=3)
    estimator.fit(X, y)
    print('Best params: ' + str(estimator.best_params_))
    print('Best score: ' + str(estimator.best_score_))

    # Test
    X_test = np.loadtxt('/content/sample_data/data/test.csv', dtype='f8', delimiter=',', skiprows=1)
    X_test = X_test.reshape(X_test.shape[0], *input_shape).astype('float32') / 255
    ids = np.arange(1, len(X_test) + 1)
    predictions = estimator.predict(X_test)
    np.savetxt('/content/sample_data/data/keras_submission.csv', np.transpose([ids, predictions]),fmt=('%d', '%d'), delimiter=',', header='ImageId,Label',comments='')

    
if __name__ == '__main__':
    main()
# Out:
# <ipython-input-6-c49b62c2fa21>:32: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   classifier = KerasClassifier(make_model, output_dim=num_classes,epochs=EPOCHS)
# Epoch 1/10
# 875/875 [==============================] - 11s 11ms/step - loss: 0.5363 - accuracy: 0.8341
# Epoch 2/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.2584 - accuracy: 0.9222
# Epoch 3/10
# 875/875 [==============================] - 9s 11ms/step - loss: 0.1942 - accuracy: 0.9419
# Epoch 4/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.1604 - accuracy: 0.9513
# Epoch 5/10
# 875/875 [==============================] - 8s 10ms/step - loss: 0.1397 - accuracy: 0.9574
# Epoch 6/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.1240 - accuracy: 0.9615
# Epoch 7/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.1103 - accuracy: 0.9664
# Epoch 8/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.0995 - accuracy: 0.9691
# Epoch 9/10
# 875/875 [==============================] - 8s 9ms/step - loss: 0.0904 - accuracy: 0.9717
# Epoch 10/10
# 875/875 [==============================] - 10s 12ms/step - loss: 0.0843 - accuracy: 0.9728
# 438/438 [==============================] - 2s 5ms/step - loss: 0.0757 - accuracy: 0.9762
# Epoch 1/10
# 875/875 [==============================] - 11s 10ms/step - loss: 0.5578 - accuracy: 0.8279
# Epoch 2/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.2740 - accuracy: 0.9147
# Epoch 3/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.2055 - accuracy: 0.9355
# Epoch 4/10
# 875/875 [==============================] - 8s 10ms/step - loss: 0.1745 - accuracy: 0.9460
# Epoch 5/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.1507 - accuracy: 0.9537
# Epoch 6/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.1364 - accuracy: 0.9569
# Epoch 7/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.1209 - accuracy: 0.9620
# Epoch 8/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.1099 - accuracy: 0.9660
# Epoch 9/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.1026 - accuracy: 0.9670
# Epoch 10/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.0946 - accuracy: 0.9680
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0879 - accuracy: 0.9745
# Epoch 1/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.5516 - accuracy: 0.8284
# Epoch 2/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.2653 - accuracy: 0.9211
# Epoch 3/10
# 875/875 [==============================] - 14s 16ms/step - loss: 0.2015 - accuracy: 0.9383
# Epoch 4/10
# 875/875 [==============================] - 11s 13ms/step - loss: 0.1659 - accuracy: 0.9496
# Epoch 5/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.1487 - accuracy: 0.9546
# Epoch 6/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.1302 - accuracy: 0.9591
# Epoch 7/10
# 875/875 [==============================] - 11s 13ms/step - loss: 0.1169 - accuracy: 0.9639
# Epoch 8/10
# 875/875 [==============================] - 12s 13ms/step - loss: 0.1045 - accuracy: 0.9668
# Epoch 9/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.1009 - accuracy: 0.9671
# Epoch 10/10
# 875/875 [==============================] - 9s 11ms/step - loss: 0.0906 - accuracy: 0.9701
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0745 - accuracy: 0.9774
# Epoch 1/10
# 875/875 [==============================] - 11s 11ms/step - loss: 0.4910 - accuracy: 0.8514
# Epoch 2/10
# 875/875 [==============================] - 11s 13ms/step - loss: 0.2098 - accuracy: 0.9373
# Epoch 3/10
# 875/875 [==============================] - 12s 14ms/step - loss: 0.1501 - accuracy: 0.9542
# Epoch 4/10
# 875/875 [==============================] - 11s 13ms/step - loss: 0.1207 - accuracy: 0.9634
# Epoch 5/10
# 875/875 [==============================] - 11s 13ms/step - loss: 0.1054 - accuracy: 0.9685
# Epoch 6/10
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0939 - accuracy: 0.9700
# Epoch 7/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0834 - accuracy: 0.9733
# Epoch 8/10
# 875/875 [==============================] - 10s 12ms/step - loss: 0.0755 - accuracy: 0.9746
# Epoch 9/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0677 - accuracy: 0.9781
# Epoch 10/10
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0633 - accuracy: 0.9792
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0712 - accuracy: 0.9789
# Epoch 1/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.5663 - accuracy: 0.8209
# Epoch 2/10
# 875/875 [==============================] - 11s 13ms/step - loss: 0.2586 - accuracy: 0.9219
# Epoch 3/10
# 875/875 [==============================] - 12s 14ms/step - loss: 0.1885 - accuracy: 0.9428
# Epoch 4/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.1529 - accuracy: 0.9525
# Epoch 5/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.1281 - accuracy: 0.9602
# Epoch 6/10
# 875/875 [==============================] - 10s 12ms/step - loss: 0.1114 - accuracy: 0.9657
# Epoch 7/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0931 - accuracy: 0.9700
# Epoch 8/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0831 - accuracy: 0.9730
# Epoch 9/10
# 875/875 [==============================] - 10s 12ms/step - loss: 0.0748 - accuracy: 0.9756
# Epoch 10/10
# 875/875 [==============================] - 9s 11ms/step - loss: 0.0708 - accuracy: 0.9766
# 438/438 [==============================] - 3s 7ms/step - loss: 0.0774 - accuracy: 0.9789
# Epoch 1/10
# 875/875 [==============================] - 14s 14ms/step - loss: 0.5113 - accuracy: 0.8431
# Epoch 2/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.2550 - accuracy: 0.9220
# Epoch 3/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.1865 - accuracy: 0.9431
# Epoch 4/10
# 875/875 [==============================] - 11s 13ms/step - loss: 0.1486 - accuracy: 0.9527
# Epoch 5/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.1277 - accuracy: 0.9618
# Epoch 6/10
# 875/875 [==============================] - 13s 14ms/step - loss: 0.1076 - accuracy: 0.9666
# Epoch 7/10
# 875/875 [==============================] - 10s 12ms/step - loss: 0.0974 - accuracy: 0.9692
# Epoch 8/10
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0863 - accuracy: 0.9719
# Epoch 9/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.0760 - accuracy: 0.9756
# Epoch 10/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0706 - accuracy: 0.9765
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0678 - accuracy: 0.9794
# Epoch 1/10
# 875/875 [==============================] - 10s 10ms/step - loss: 0.5427 - accuracy: 0.8278
# Epoch 2/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.2156 - accuracy: 0.9367
# Epoch 3/10
# 875/875 [==============================] - 8s 9ms/step - loss: 0.1520 - accuracy: 0.9545
# Epoch 4/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.1228 - accuracy: 0.9645
# Epoch 5/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.1020 - accuracy: 0.9706
# Epoch 6/10
# 875/875 [==============================] - 8s 9ms/step - loss: 0.0850 - accuracy: 0.9741
# Epoch 7/10
# 875/875 [==============================] - 9s 11ms/step - loss: 0.0748 - accuracy: 0.9772
# Epoch 8/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.0676 - accuracy: 0.9797
# Epoch 9/10
# 875/875 [==============================] - 8s 9ms/step - loss: 0.0591 - accuracy: 0.9814
# Epoch 10/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.0502 - accuracy: 0.9845
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0848 - accuracy: 0.9761
# Epoch 1/10
# 875/875 [==============================] - 11s 10ms/step - loss: 0.5667 - accuracy: 0.8244
# Epoch 2/10
# 875/875 [==============================] - 8s 9ms/step - loss: 0.1844 - accuracy: 0.9469
# Epoch 3/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.1269 - accuracy: 0.9625
# Epoch 4/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.0990 - accuracy: 0.9705
# Epoch 5/10
# 875/875 [==============================] - 8s 9ms/step - loss: 0.0837 - accuracy: 0.9752
# Epoch 6/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.0709 - accuracy: 0.9790
# Epoch 7/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.0611 - accuracy: 0.9807
# Epoch 8/10
# 875/875 [==============================] - 8s 9ms/step - loss: 0.0540 - accuracy: 0.9839
# Epoch 9/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.0463 - accuracy: 0.9859
# Epoch 10/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.0418 - accuracy: 0.9876
# 438/438 [==============================] - 4s 8ms/step - loss: 0.0910 - accuracy: 0.9769
# Epoch 1/10
# 875/875 [==============================] - 11s 11ms/step - loss: 0.5533 - accuracy: 0.8280
# Epoch 2/10
# 875/875 [==============================] - 8s 9ms/step - loss: 0.2174 - accuracy: 0.9369
# Epoch 3/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.1539 - accuracy: 0.9563
# Epoch 4/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.1190 - accuracy: 0.9654
# Epoch 5/10
# 875/875 [==============================] - 8s 9ms/step - loss: 0.1009 - accuracy: 0.9701
# Epoch 6/10
# 875/875 [==============================] - 10s 12ms/step - loss: 0.0830 - accuracy: 0.9759
# Epoch 7/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.0740 - accuracy: 0.9777
# Epoch 8/10
# 875/875 [==============================] - 8s 9ms/step - loss: 0.0628 - accuracy: 0.9800
# Epoch 9/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.0552 - accuracy: 0.9823
# Epoch 10/10
# 875/875 [==============================] - 9s 10ms/step - loss: 0.0455 - accuracy: 0.9851
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0793 - accuracy: 0.9777
# Epoch 1/10
# 875/875 [==============================] - 12s 12ms/step - loss: 0.4983 - accuracy: 0.8444
# Epoch 2/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.1849 - accuracy: 0.9467
# Epoch 3/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.1269 - accuracy: 0.9634
# Epoch 4/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0996 - accuracy: 0.9703
# Epoch 5/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.0796 - accuracy: 0.9770
# Epoch 6/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0671 - accuracy: 0.9794
# Epoch 7/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0602 - accuracy: 0.9808
# Epoch 8/10
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0528 - accuracy: 0.9839
# Epoch 9/10
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0457 - accuracy: 0.9856
# Epoch 10/10
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0408 - accuracy: 0.9871
# 438/438 [==============================] - 2s 4ms/step - loss: 0.0813 - accuracy: 0.9789
# Epoch 1/10
# 875/875 [==============================] - 12s 12ms/step - loss: 0.5084 - accuracy: 0.8448
# Epoch 2/10
# 875/875 [==============================] - 10s 12ms/step - loss: 0.1956 - accuracy: 0.9443
# Epoch 3/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.1294 - accuracy: 0.9627
# Epoch 4/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0979 - accuracy: 0.9709
# Epoch 5/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0783 - accuracy: 0.9768
# Epoch 6/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0665 - accuracy: 0.9804
# Epoch 7/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0556 - accuracy: 0.9842
# Epoch 8/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.0455 - accuracy: 0.9868
# Epoch 9/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0389 - accuracy: 0.9882
# Epoch 10/10
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0333 - accuracy: 0.9893
# 438/438 [==============================] - 2s 5ms/step - loss: 0.0908 - accuracy: 0.9781
# Epoch 1/10
# 875/875 [==============================] - 12s 12ms/step - loss: 0.5264 - accuracy: 0.8361
# Epoch 2/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.2050 - accuracy: 0.9397
# Epoch 3/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.1370 - accuracy: 0.9591
# Epoch 4/10
# 875/875 [==============================] - 10s 12ms/step - loss: 0.1037 - accuracy: 0.9702
# Epoch 5/10
# 875/875 [==============================] - 10s 12ms/step - loss: 0.0859 - accuracy: 0.9738
# Epoch 6/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0715 - accuracy: 0.9788
# Epoch 7/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0601 - accuracy: 0.9818
# Epoch 8/10
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0506 - accuracy: 0.9841
# Epoch 9/10
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0452 - accuracy: 0.9860
# Epoch 10/10
# 875/875 [==============================] - 10s 11ms/step - loss: 0.0380 - accuracy: 0.9883
# 438/438 [==============================] - 3s 5ms/step - loss: 0.0764 - accuracy: 0.9806
# Epoch 1/10
# 1313/1313 [==============================] - 17s 12ms/step - loss: 0.4020 - accuracy: 0.8788
# Epoch 2/10
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.1350 - accuracy: 0.9611
# Epoch 3/10
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.0982 - accuracy: 0.9715
# Epoch 4/10
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.0790 - accuracy: 0.9770
# Epoch 5/10
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.0637 - accuracy: 0.9807
# Epoch 6/10
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.0547 - accuracy: 0.9837
# Epoch 7/10
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.0468 - accuracy: 0.9857
# Epoch 8/10
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.0402 - accuracy: 0.9871
# Epoch 9/10
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.0344 - accuracy: 0.9890
# Epoch 10/10
# 1313/1313 [==============================] - 16s 12ms/step - loss: 0.0293 - accuracy: 0.9905
# Best params: {'dense_layer_sizes': [32, 32], 'filters': 16}
# Best score: 0.9792142907778422
# 875/875 [==============================] - 4s 4ms/step

# %% [markdown]
# Hay varias formas de mejorar este modelo como:
#
# - Aumentar el número de capas convolucionales.
# - Agregar capas de normalización.
# - Ajustar la tasa de aprendizaje.
# - Cambiar la arquitectura del modelo.
# - Aumentar el número de épocas de entrenamiento
#
# Despues de intentar varios codigos diferentes y todos ellos tardar muchisimo tiempo en generarse, he decidio quedarme con este en el que aumento las capas convolucionales a 2, agrego 2 capas densas y subo las epocas a 30. En el codigo propuesto se utiliza una sola capa convolucional seguida de una capa de aplanamiento y capas densas, mientras que mi propuesta se utiliza múltiples capas convolucionales y de agrupación seguidas de una capa de aplanamiento y capas densas.
#
# En lugar de utilizar KerasClassifier y GridSearchCV, se utiliza una estrategia de validación cruzada (StratifiedKFold) para evaluar el modelo y compilarlo con una función de pérdida de entropía cruzada dispersa. El entrenamiento se realiza utilizando bucles de validación cruzada, y después de entrenar el modelo, se realiza una predicción en el conjunto de prueba y se guarda tambien en un archivo CSV llamado "keras_submission_capas_convolucionales.csv".
#
# Al ejecutar el codigo  da un Average mayor que el porcionado en la practica 0.9792 vs 0.9939 por lo que considero que es significativamente mejor.

# %%
from sklearn.model_selection import StratifiedKFold
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
import numpy as np
import tensorflow as tf


# Establece la sesión de TensorFlow
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 0.9
config.allow_soft_placement = True
tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))

EPOCHS = 30
BATCH_SIZE = 64
LEARNING_RATE = 0.001

def make_model(input_shape, num_classes, filters, kernel_size, pool_size, hidden_units):
    model = Sequential()
    for i, num_filter in enumerate(filters):
        if i == 0:
            model.add(Conv2D(num_filter, kernel_size=kernel_size, activation='relu', input_shape=input_shape))
        else:
            model.add(Conv2D(num_filter, kernel_size=kernel_size, activation='relu'))
        model.add(MaxPooling2D(pool_size=pool_size))
    model.add(Flatten())
    for units in hidden_units:
        model.add(Dense(units, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    return model

def main():
    data = np.loadtxt('/content/sample_data/data/train.csv', dtype='f8', delimiter=',', skiprows=1)
    X, y = data[:, 1:], data[:, 0]
    input_shape = (28, 28, 1)
    
    num_classes = len(np.unique(y))
    model = make_model(input_shape=input_shape, num_classes=num_classes, filters=[20, 40],
                       kernel_size=(3, 3), pool_size=(2, 2), hidden_units=[32])

    # Entreno y evalúo el modelo usando validación cruzada
    skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    scores = []
    for train_index, val_index in skf.split(X, y):
        X_train, X_val = X[train_index], X[val_index]
        y_train, y_val = y[train_index], y[val_index]

        X_train = X_train.reshape(X_train.shape[0], *input_shape).astype('float32') / 255
        X_val = X_val.reshape(X_val.shape[0], *input_shape).astype('float32') / 255

        model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
        model.fit(X_train, y_train, epochs=EPOCHS, verbose=0)

        _, accuracy = model.evaluate(X_val, y_val, verbose=0)
        scores.append(accuracy)

    print('Average score: ' + str(np.mean(scores)))

    X_test = np.loadtxt('/content/sample_data/data/test.csv', dtype='f8', delimiter=',', skiprows=1)
    X_test = X_test.reshape(X_test.shape[0], *input_shape).astype('float32') / 255

    model.fit(X.reshape(X.shape[0], *input_shape).astype('float32') / 255, y, epochs=EPOCHS, verbose=0)

    predictions = model.predict(X_test)
    predicted_labels = np.argmax(predictions, axis=1)

    # Guardar las predicciones en un archivo CSV
    output = np.column_stack((np.arange(1, len(predicted_labels) + 1), predicted_labels))
    np.savetxt('/content/sample_data/data/keras_submission_capas_convolucionales.csv', output, header='ImageId,Label', delimiter=',', fmt='%d', comments='')

if __name__ == '__main__':
    main()
# Out:
# Average score: 0.9939761956532797
# 875/875 [==============================] - 6s 6ms/step
